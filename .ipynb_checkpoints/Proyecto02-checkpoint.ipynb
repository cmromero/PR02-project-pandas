# %%
Image('Proyecto02_portada.jpg')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Fase-de-importación" data-toc-modified-id="Fase-de-importación-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Fase de importación</a></span></li><li><span><a href="#Fase-de-exploración-de-columnas-o-observaciones" data-toc-modified-id="Fase-de-exploración-de-columnas-o-observaciones-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Fase de exploración de columnas o observaciones</a></span></li><li><span><a href="#Fase-limpieza" data-toc-modified-id="Fase-limpieza-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Fase limpieza</a></span><ul class="toc-item"><li><span><a href="#Eliminar-columnas-y-filas-innecesarias-o-conflictivas" data-toc-modified-id="Eliminar-columnas-y-filas-innecesarias-o-conflictivas-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Eliminar columnas y filas innecesarias o conflictivas</a></span></li><li><span><a href="#Depurar-y-eliminar-valores-nulos-de-la-columna-'href'" data-toc-modified-id="Depurar-y-eliminar-valores-nulos-de-la-columna-'href'-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Depurar y eliminar valores nulos de la columna 'href'</a></span></li><li><span><a href="#Substituimos-valores-nulos-por-string-'Unknown'-en-columnas-que-no-usaremos" data-toc-modified-id="Substituimos-valores-nulos-por-string-'Unknown'-en-columnas-que-no-usaremos-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Substituimos valores nulos por string 'Unknown' en columnas que no usaremos</a></span></li><li><span><a href="#Depurar-y-eliminar-valores-nulos-de-la-columna-'Fatal-(Y/N)'" data-toc-modified-id="Depurar-y-eliminar-valores-nulos-de-la-columna-'Fatal-(Y/N)'-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Depurar y eliminar valores nulos de la columna 'Fatal (Y/N)'</a></span></li><li><span><a href="#Depurar-y-completar-los-valores-de-las-columnas-'Area',--'Country'-y-'Location'" data-toc-modified-id="Depurar-y-completar-los-valores-de-las-columnas-'Area',--'Country'-y-'Location'-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Depurar y completar los valores de las columnas 'Area',  'Country' y 'Location'</a></span></li><li><span><a href="#Depurar-los-valores-del-campo-'Sex--'" data-toc-modified-id="Depurar-los-valores-del-campo-'Sex--'-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Depurar los valores del campo 'Sex  '</a></span></li><li><span><a href="#Informar-com-John/Jane-Doe-a-los-nombres-que-estén-vacios-pero-con-sexo-determinado" data-toc-modified-id="Informar-com-John/Jane-Doe-a-los-nombres-que-estén-vacios-pero-con-sexo-determinado-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Informar com John/Jane Doe a los nombres que estén vacios pero con sexo determinado</a></span></li><li><span><a href="#Depurar-campo-'Activity'-y-agrupar-actividades-en-un-campo-adicional" data-toc-modified-id="Depurar-campo-'Activity'-y-agrupar-actividades-en-un-campo-adicional-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Depurar campo 'Activity' y agrupar actividades en un campo adicional</a></span></li><li><span><a href="#Depuramos-la-columna-'year'-a-partir-de-la-columna-'Date'" data-toc-modified-id="Depuramos-la-columna-'year'-a-partir-de-la-columna-'Date'-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Depuramos la columna 'year' a partir de la columna 'Date'</a></span></li><li><span><a href="#Agrupamos-los-países-en-una-nueva-columna-llamada-'Territories'" data-toc-modified-id="Agrupamos-los-países-en-una-nueva-columna-llamada-'Territories'-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Agrupamos los países en una nueva columna llamada 'Territories'</a></span></li></ul></li><li><span><a href="#Fase-final-de-exportación" data-toc-modified-id="Fase-final-de-exportación-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Fase final de exportación</a></span></li><li><span><a href="#Fase-de-consulta:-Where-did-Fonzie-jump-de-shark???" data-toc-modified-id="Fase-de-consulta:-Where-did-Fonzie-jump-de-shark???-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Fase de consulta: Where did Fonzie jump de shark???</a></span></li></ul></div>

# %% [markdown]
# ## Fase de importación

# %%
import pandas as pd
import re
import numpy as np
from IPython.display import HTML
from IPython.display import Image

# %%
#importacion de fichero descargado por gi
df= pd.read_csv('data/GSAF5.csv', encoding='latin-1')
#importacion de un listado de países/territorios de enlace de github que posteriorment utilizaremos
df_world= pd.read_csv('data/world.csv')

# %% [markdown]
# ## Fase de exploración de columnas o observaciones

# %%
#obtenemos una muestra
df.head(4)
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
#
#   Species        Investigator or Source                        pdf  \
# 0      NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1      NaN  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2      NaN  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# ...

# %%
#intentamos obtener más información de las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
#intetar averiguar porque hay dos columnas con 'Case Nº 1' y 'Case Nº 2'
df[df['Case Number']=='2016.09.15']
#viendo un ejemplo se comprueba que las columnas son irrelevantes
# Out:
#   Case Number       Date  Year        Type    Country      Area     Location  \
# 4  2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria  Bells Beach
#
#   Activity  Name Sex   ...   Species  Investigator or Source  \
# 4  Surfing  male    M  ...  2 m shark     The Age, 9/16/2016
#
#                          pdf  \
# 4  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 4    2016.09.15           5989         NaN         NaN
#
# [1 rows x 24 columns]

# %%
#intentamos averiguar que hay en los campos con enlaces
print(df.at[4,"href formula"])
print(df.at[4,"href"])
#parece que son la ruta del pdf del expediente del caso registrado (se duplica)
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.16-BellsBeach.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.16-BellsBeach.pdf

# %%
#comprobamos que hay en Time
print(df.at[10,"Time"])
# Out:
# Late afternoon

# %%
#comprobamos los tipos de datos de las columnas y imprimimos el primer registro como ejemplo
print(df.dtypes)
print('-'*80)
print(df.iloc[0])
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Fase limpieza

# %% [markdown]
# ### Eliminar columnas y filas innecesarias o conflictivas

# %%
#eliminamos las columnas irrelevantes
df.drop(["href formula",'Unnamed: 22', 'Unnamed: 23','Case Number.1', 'Case Number.2','pdf','original order'],axis=1,inplace=True)

# %%
#eliminamos las columnas conflictivas por tener demasiados valores nulos
'''en comparación con el número de filas (5992) hay demasiado valores nulos en las columnas ['Age','Time','Species'] 
y, por tanto, decido que es mejor eliminarlas'''
df.drop(['Age','Time','Species '],axis=1,inplace=True)
#comprobamos missing values de cada columna
df.isna().sum()
# Out:
# Case Number                 0
# Date                        0
# Year                        0
# Type                        0
# Country                    43
# Area                      402
# Location                  496
# Activity                  527
# Name                      200
# Sex                       567
# Injury                     27
# Fatal (Y/N)                19
# Investigator or Source     15
# href                        3
# dtype: int64

# %% [markdown]
# ### Depurar y eliminar valores nulos de la columna 'href'

# %%
#renombrar href por "path pdf"
df.rename(columns={'href':'pdf_path'},inplace=True)

# %%
#averiguar los pdf vacios
df[df['pdf_path'].isnull()]

# eliminarlos por no ser comprobables
df.drop(df[df['pdf_path'].isnull()].index,inplace=True)

# %% [markdown]
# ### Substituimos valores nulos por string 'Unknown' en columnas que no usaremos

# %%
#subtituimos valores nulos por 'Unknown'
df['Injury'].fillna('Unknown', inplace=True)
df['Investigator or Source'].fillna('Unknown', inplace=True)

# %% [markdown]
# ### Depurar y eliminar valores nulos de la columna 'Fatal (Y/N)'

# %%
#Creamos un dataframe con los campos 'Fatal (Y/N)' vacíos y que en el campo 'injury' indique que haya sido un accidente mortal
fatal_injury_and_null = df[df['Fatal (Y/N)'].isnull() & df['Injury'].str.contains('FATAL|remains|[Dd]eath', regex=True)==True]

#informamos del valor correcto en 'Fatal (Y/N)'
fatal_injury_and_null.loc[:,'Fatal (Y/N)']='Y'

#eliminamos los registros antiguos del df original y añadimos los registros actualizados
df.drop(df[df['Fatal (Y/N)'].isnull() & df['Injury'].str.contains('FATAL|remains|[Dd]eath', regex=True)==True].index,inplace=True)
df=pd.concat([df, fatal_injury_and_null],axis=0)

#informamos a los demás registros con campos 'Fatal (Y/N)' vacíos como accidente NO mortal
df.loc[df['Fatal (Y/N)'].isnull(),'Fatal (Y/N)']='N'
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ### Depurar y completar los valores de las columnas 'Area',  'Country' y 'Location'

# %%
#examinamos lista de países
Countries=df['Country'].unique()

#examinamos los países que están vacios y informamos aquellos que veamos que se puede deducir el país a partir de 'Area'
#1) creo un df con los registros de país vacíos
df3=df[df['Country'].isnull()]

#2) Hago las modificaciones en el nuevo df
df3['Area']=df3['Area'].str.replace('(Between)|(Near the)|(Darwin, )|(300 miles east of St. Thomas )','',regex=True)
df3['Area']=df3['Area'].str.replace('&','/')
df3['Area']=df3['Area'].str.replace(r"\(","")
df3['Area']=df3['Area'].str.replace(r"\)","")
df3['Area']=df3['Area'].str.replace('(French Southern Territories)','FRANCE',regex=True)
df3['Area']=df3['Area'].str.replace('(English Channel)','ATLANTIC OCEAN',regex=True)
df3['Area']=df3['Area'].str.replace('(Ionian Sea)','MEDITERRANEAN SEA',regex=True)
df3['Area']=df3['Area'].str.replace('(Off South American coast)|(Western Banks)','Unkown',regex=True)
df3['Area']=df3['Area'].str.strip()
df3['Area']=df3['Area'].str.upper()
df3['Area'].fillna('UNKOWN', inplace=True)

#3) Completamos los datos vacios de 'country' con los datos existentes de 'Area'
df3.loc[df['Country'].isnull(),'Country']=df3['Area']

#eliminamos los registros antiguos del df original y añadimos los registros actualizados
df.drop(df[df['Country'].isnull()].index,inplace=True)
df=pd.concat([df, df3],axis=0)

#arreglar valores nulos de area a partir de información de 'Location' y, sinó, de 'Country'
df6=df[df['Area'].isnull()]

#itinerar para sacar las areas donde location es una area en otro registro
list_areas=df['Area'].unique()
for c in df6.columns:
    if c!='Location':
        pass
    else:
        for i in df6.index:
            if df6.at[i,c] in list_areas:
                df6.at[i,'Area']=df6.at[i,c]
            else:
                pass

#itinerar para sacar las areas donde location es un Country en otro registro            
country_list=[x.title() for x in Countries.tolist() if isinstance(x, str)]
for c in df6.columns:
    if c!='Location':
        pass
    else:
        for i in df6.index:
            if df6.at[i,c] in country_list:
                df6.at[i,'Area']=df6.at[i,c]
            else:
                pass

#substituir las areas vacias con location informada por "Una área de..."            
df6.loc[df6['Location'].notnull(),'Area']=("The area of "+df6['Location']) 

#Substituir el resto de valores nulos por "Unkown area"
df6['Area'].fillna('Unknown area', inplace=True)

df.drop(df[df['Area'].isnull()].index,inplace=True)
df=pd.concat([df, df6],axis=0)

#Substituimos directamente los valores nulos por "Unkown location" ya que no podemos estimar la localización con la información dada
df['Location'].fillna('Unknown location', inplace=True)
# Out:
# <ipython-input-15-2eef7b8c555a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Area']=df3['Area'].str.replace('(Between)|(Near the)|(Darwin, )|(300 miles east of St. Thomas )','',regex=True)
# <ipython-input-15-2eef7b8c555a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Area']=df3['Area'].str.replace('&','/')
# <ipython-input-15-2eef7b8c555a>:11: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %% [markdown]
# ### Depurar los valores del campo 'Sex  '

# %%
df['Sex '].unique()
# Out:
# array(['M', nan, 'F', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
df['Sex '].unique()
df.loc[df['Sex '].str.contains('M ', case=False, na=False), 'Sex '] = 'M'
df.loc[~df['Sex '].str.contains('M|F',regex=True,na=False),'Sex ']='UNKOWN'
df.loc[df['Sex '].isna(), 'Sex '] = 'UNKOWN'


df4 = df[df['Sex ']=='UNKOWN']
df4.loc[df4['Name'].str.contains('(male)|(m[ea]n)',case=False, na=False, regex=True),'Sex '] = 'M'
df4.loc[df4['Name'].str.contains('(female)|(wom[ea]n)',case=False, na=False, regex=True),'Sex '] = 'F'

df.drop(df[df['Sex ']=='UNKOWN'].index,inplace=True)
df=pd.concat([df, df4],axis=0)

print(df['Sex '].value_counts())
# Out:
# M         4883
# F          587
# UNKOWN     519
# Name: Sex , dtype: int64
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ### Informar com John/Jane Doe a los nombres que estén vacios pero con sexo determinado

# %%
#substituir nombre vacios por John Doe & Jane Doe
df5=df[df['Name'].isnull()]
df5.loc[df5['Sex ']=='M','Name']="John Doe"
df5.loc[df5['Sex ']=='F','Name']="Jane Doe"
df5.loc[df5['Sex ']=='UNKOWN','Name']="Unkown"

df.drop(df[df['Name'].isnull()].index,inplace=True)
df=pd.concat([df, df5],axis=0)

#reemplazar nombres de male o female por John/Jane Doe
df["Name"].replace({"male": "John Doe", "female": "Jane Doe", "Male": "John Doe"}, inplace=True)

# %% [markdown]
# ### Depurar campo 'Activity' y agrupar actividades en un campo adicional

# %%
#comprobamos el tipo de datos que hay dentre de 'Activity'
df['Activity'].apply(type)
df['Activity'] = df['Activity'].astype(str)

# %%
#Substituimos los valores nulos de activity por "Unkown activity"
df['Activity'].fillna('Unknown activity', inplace=True)
df.loc[df['Activity']=='nan', 'Activity'] = 'Unknown activity'

#convertimos todos los valores a texto:
df['Activity'] = df['Activity'].astype(str)

#miramos las actividades más recurentes
df.groupby('Activity', sort=False)['Case Number'].count().nlargest(30)
df['Activity_type']=""

#las agrupamos en categorias
surf=re.compile('([Ss]urfing)|([Bb]oarding)|([Pp]addle)')
dive=re.compile('([Dd]iving)|([Ss]norkeling)')
fish=re.compile('([Ff]ish)|([Hh]unt)|([Tt]rap)|([Aa]quarium)|([Pp]ull)|([Pp]ick)|([Ll]obster)')
boat=re.compile('([Cc]anoe)|([Oo]verboard)|([Kk]ayak)|([Rr]owing)|([Bb]oat)|([Ss]ail)')
swim=re.compile('([Ss]wim)|([Ss]tand)|([Bb]ath)|([Tt]reading)|([Ww]alk)|([Ww]ading)|([Ff]loat)|([Ss]itting)|([iI]n the water)|([Jj]ump)|([Ss]plash)')
unkown=re.compile('([Uu]nknown)')
fooling=re.compile('([Tt]easing)|([Pp]laying)|([Pp]rovok)|([Hh]and feed)|([Pp]etting)')
docum=re.compile('([Pp]hoto)|([Ff]ilm)|[Tt]agging')
accident=re.compile('([Dd]isaster)|([Ww]reck)')
        
def group_activity(act):
    s=surf.search(act)
    d=dive.search(act)
    f=fish.search(act)
    b=boat.search(act)
    sw=swim.search(act)
    u=unkown.search(act)
    fo=fooling.search(act)
    dc=docum.search(act)
    ac=accident.search(act)
    if s:
        return "Surfing"
    elif d:
        return "Diving"
    elif f:
        return "Fishing"
    elif b:
        return "Activity on a boat"
    elif sw:
        return "Swimming"
    elif u:
        return "Unknow"
    elif fo:
        return "Fooling arround with sharks"
    elif dc:
        return "Documenting sharks"
    elif ac:
        return "Accident"
    else:
        return "Other activities"
    
df['Activity_type']=df['Activity'].apply(lambda x: group_activity(x))

#comprobamos las agrupaciones
df['Activity_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#chequeamos la nueva columna de agrupación
df[df['Activity_type']=='Unknow']
# Out:
#        Case Number          Date  Year        Type       Country  \
# 1575    2003.01.17     17-Jan-03  2003     Invalid  SOUTH AFRICA
# 1751    2001.02.11     11-Feb-01  2001     Invalid      MALAYSIA
# 1991    1997.11.05   05-Nov-1997  1997     Invalid     AUSTRALIA
# 5781  1842.00.00.a          1842  1842  Unprovoked     AUSTRALIA
#
#          Territory                                          Area  \
# 1575  SOUTH AFRICA                         Western Cape Province
# 1751      MALAYSIA  Off the western coast of peninsular Malaysia
# 1991     AUSTRALIA                               New South Wales
# 5781     AUSTRALIA                               New South Wales
#
#                                            Location  \
# 1575  Near the lagoon at Table View, Cape Peninsula
# 1751                 Pulau Pangkor (Pangkor Island)
# 1991                                    Botany Bay?
# 5781                                  Sydney Harbor
#
# ...

# %% [markdown]
# ### Depuramos la columna 'year' a partir de la columna 'Date'

# %%
#analizamos columna year
df.groupby('Year').count()
#suponemos que los valores con menos de 4 dígitos son erroneos y le damos valor 0
df.loc[df['Year']<1000, 'Year'] = 0
#de los años vacíos intentamos extraer año de la columna 'Date'
df_y0=df[df['Year']==0]
years=re.compile('\d{4}')
df_y0['year_from_date']=""

def take_year(date):
    y=years.search(date)
    if y:
        return int(y.group())
    else:
        return 0
    
df_y0['year_from_date']=df_y0['Date'].apply(lambda x: take_year(x))

#substituimos el valor vacío de 'Year' por el que hay en 'year_from_date'
df_y0.loc[df_y0['year_from_date']!=0, 'Year'] = df_y0['year_from_date']
#eliminamos columna 'year_from_date'
df_y0=df_y0.drop(columns=['year_from_date'])

#actualizamos columna year en el df original
df.drop(df[df['Year']==0].index,inplace=True)
df=pd.concat([df, df_y0],axis=0)
df.drop(df[df['Year']==0].index,inplace=True)

#volvemos a analizar columna year
df.groupby('Year').count()
df.Year=df.Year.astype(int)
df.head(1)
# Out:
#     Case Number       Date  Year        Type Country Territory     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA       USA  Florida
#
#                            Location Activity Activity_type      Name Sex   \
# 0  New Smyrna Beach, Volusia County  Surfing       Surfing  John Doe    M
#
#                   Injury Fatal (Y/N)       Investigator or Source  \
# 0  Minor injury to thigh           N  Orlando Sentinel, 9/19/2016
#
#                                             pdf_path
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# ### Agrupamos los países en una nueva columna llamada 'Territories'

# %%
#examinamos nuevamente los países disponibles en "Country"
Countries
#arreglamos los países que salen con ? o Between... &...
df['Country']=df['Country'].str.upper()
df['Country']=df['Country'].str.replace('Between PORTUGAL & INDIA','PORTUGAL / INDIA')
df['Country']=df['Country'].str.replace('?','')
df['Country']=df['Country'].str.replace('&','AND')
df['Country']=df['Country'].str.replace('(St )|([Ss][tT]\.)','SAINT ',case=None,regex=True)
df['Country']=df['Country'].str.replace('CEYLON (SRI LANKA)','SRI LANKA',regex=False)
df['Country']=df['Country'].str.replace('UNITED ARAB EMIRATES (UAE)','UNITED ARAB EMIRATES',regex=False)
df['Country']=df['Country'].str.strip()
df['Country']=df['Country'].str.rstrip()

#creamos una nueva columna para clasificar mejor los países y territorios
df['Territory']=df['Country']
df.loc[df['Territory'].str.contains('/', regex=False)==True, 'Territory'] = 'BETWEEN TWO COUNTRIES'
df.loc[df['Territory'].str.contains('(SEA)|(OCEAN)|(GULF)|(COAST)|(BAY)|(PACIFIC)|(ASIA)', case=False, regex=True)==True, 'Territory'] = 'INTERNATIONAL WATERS'

#eliminamos los acentos en los nombres de los países del df de word previamente importado
df_world['name']=df_world['name'].str.replace('á','a',regex=False)
df_world['name']=df_world['name'].str.replace('é','e',regex=False)
df_world['name']=df_world['name'].str.replace('í','i',regex=False)
df_world['name']=df_world['name'].str.replace('ó','o',regex=False)
df_world['name']=df_world['name'].str.replace('ú','u',regex=False)
list_world=df_world['name'].str.upper().to_list()
list_acro=df_world['alpha3'].str.upper().to_list()

for i in df.index:
    if df.at[i,'Territory'] in list_world:
        pass
    elif df.at[i,'Territory'] in list_acro:
        pass
    elif df.at[i,'Territory'] == 'BETWEEN TWO COUNTRIES':
        pass
    elif df.at[i,'Territory'] == 'INTERNATIONAL WATERS':
        pass
    elif df.at[i,'Territory'] == 'UNKOWN':
        df.at[i,'Territory']='UNKOWN TERRITORY'
    else:
        df.at[i,'Territory']='OTHER TERRITORIES'

#comprobamos los countries que no se relacionan y los reemplazamos 
df.loc[(df['Country']=='ENGLAND') | (df['Country']=='UNITED KINGDOM') | (df['Country']=='SCOTLAND'), 'Territory'] = 'UNITED KINGDOM'
df.loc[df['Country']=='IRAN', 'Territory'] = df['Country']
df.loc[df['Country']=='VIETNAM', 'Territory'] = df['Country']
df.loc[df['Country']=='VENEZUELA', 'Territory'] = df['Country']
df.loc[df['Country']=='COLUMBIA', 'Territory'] = 'COLOMBIA'
df.loc[df['Country']=='TAIWAN', 'Territory'] = df['Country']
df.loc[df['Country']=='SOUTH KOREA', 'Territory'] = df['Country']
df.loc[df['Country']=='TANZANIA', 'Territory'] = df['Country']
df.loc[df['Country']=='YEMEN ', 'Territory'] = df['Country']
df.loc[df['Country']=='OKINAWA', 'Territory'] = 'JAPAN'
df.loc[df['Country']=='NEW BRITAIN', 'Territory'] = 'NEW GUINEA'
df.loc[df['Country']=='TURKS AND CAICOS', 'Territory'] = df['Country']
df.loc[df['Country']=='NEW GUINEA', 'Territory'] = df['Country']
df.loc[df['Country']=='AZORES', 'Territory'] = 'PORTUGAL'
df.loc[df['Country']=='BURMA', 'Territory'] = 'MYANMAR'
df.loc[df['Country']=='RUSSIA', 'Territory'] = df['Country']
df.loc[df['Country']=='CAPE VERDE', 'Territory'] = df['Country']
df.loc[df['Country']=='EGYPT', 'Territory'] = df['Country']

#df.groupby('Territory', sort=False)['Case Number'].count().nlargest(30) #<= codigo de comprobación

#df[df['Territory']=='OTHER TERRITORIES'].groupby('Country', sort=False)['Case Number'].count().nlargest(30) <= codigo de comprobación
# Out:
# <ipython-input-42-7a491adcc416>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Country']=df['Country'].str.replace('?','')
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Territory
# USA                     2114
# AUSTRALIA               1275
# SOUTH AFRICA             563
# PAPUA NEW GUINEA         131
# NEW ZEALAND              124
# INTERNATIONAL WATERS     109
# BRAZIL                   102
# BAHAMAS                   98
# MEXICO                    81
# ITALY                     70
# FIJI                      65
# PHILIPPINES               60
# REUNION                   56
# NEW CALEDONIA             51
# MOZAMBIQUE                44
# ...

# %% [markdown]
# ## Fase final de exportación

# %%
#reordenamos las columnas del df
column_names=['Case Number','Date','Year','Type','Country','Territory','Area','Location','Activity','Activity_type','Name',
              'Sex ','Injury','Fatal (Y/N)','Investigator or Source','pdf_path']
df=df.reindex(columns=column_names)
df.head(1)
# Out:
#     Case Number       Date  Year        Type Country Territory     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA       USA  Florida
#
#                            Location Activity Activity_type      Name Sex   \
# 0  New Smyrna Beach, Volusia County  Surfing       Surfing  John Doe    M
#
#                   Injury Fatal (Y/N)       Investigator or Source  \
# 0  Minor injury to thigh           N  Orlando Sentinel, 9/19/2016
#
#                                             pdf_path
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
#Exportamos la base de datos a un fichero csv
df.to_csv('data\jumptheshark.csv', encoding='latin-1')

# %% [markdown]
# ## Fase de consulta: Where did Fonzie jump de shark???

# %%
# Video de youtube
HTML('<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Tk_y_r5cXZs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Tk_y_r5cXZs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
#Filter by the years where the show was setting
years_show=list(range(1955,1970))
results=df[df.Year.isin(years_show)]
nrows=len(results.index)
print(f'There is {nrows} matches')
# Out:
# There is 930 matches

# %%
#Filter by the place where the event happened in the episode
results=results[results.Territory=='USA'][results.Area=='California']
nrows=len(results.index)
print(f'There is {nrows} matches')
# Out:
# There is 56 matches
# <ipython-input-27-970bee19fd29>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results=results[results.Territory=='USA'][results.Area=='California']

# %%
#Filter by the gender of the serie's character, The Fonze
results=results[results['Sex ']=='M']
nrows=len(results.index)
print(f'There is {nrows} matches')
# Out:
# There is 44 matches

# %%
#Filter by the kind of activity 'the Fonze' was doing while jumping the shark
results=results[results['Activity_type']=='Surfing']
nrows=len(results.index)
print(f'There is {nrows} matches')
# Out:
# There is 3 matches

# %%
#Filter by the fact that 'The Fonze' didn't die
results=results[results['Fatal (Y/N)']=='N']
nrows=len(results.index)
print(f'There is {nrows} matches')
# Out:
# There is 2 matches

# %%
#Filter by the latest year of the case because that episode was one of the last ones
fonzie_case=results.nlargest(1,'Year')
fonzie_case
# Out:
#        Case Number  Date  Year      Type Country Territory        Area  \
# 3417  1965.00.00.f  1965  1965  Provoked     USA       USA  California
#
#                                      Location Activity Activity_type  \
# 3417  Dana Point, San Clemente, Orange County  Surfing       Surfing
#
#             Name Sex                                              Injury  \
# 3417  Barry Berg    M  Puncture wounds to foot when he stepped on a s...
#
#      Fatal (Y/N)             Investigator or Source  \
# 3417           N  Orange County Register, 1/28/2998
#
#                                                pdf_path
# 3417  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
#But... what happened to Fonzie after jumping the shark??
print(f'''The result was as follows: 
{fonzie_case.iloc[0, 12]}''')
# Out:
# The result was as follows:
# Puncture wounds to foot when he stepped on a shark    PROVOKED INCIDENT
